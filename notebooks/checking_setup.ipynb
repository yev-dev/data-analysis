# %% [markdown]
# # Checking your setup
# Run through this notebook to make sure your environment is properly setup. Be sure to launch Jupyter from inside the virtual environment.

# %%
from check_environment import run_checks
run_checks()
# Out:
# Using Python in /usr/local/anaconda3/envs/tsa:
# [ OK ] Python is version 3.9.18 | packaged by conda-forge | (main, Dec 23 2023, 16:36:46)
# [Clang 16.0.6 ]
#
# [ OK ] anyio
# [ OK ] appdirs
# [ OK ] appnope
# [ OK ] argon2_cffi
# [ OK ] argon2_cffi_bindings
# [ OK ] arrow
# [ OK ] asttokens
# [ OK ] async_lru
# [ OK ] attrs
# [ OK ] babel
# [ OK ] beautifulsoup4
# [ OK ] bleach
# [ OK ] certifi
# [ OK ] cffi
# [ OK ] charset_normalizer
# [ OK ] comm
# [ OK ] contourpy
# [ OK ] cycler
# [ OK ] debugpy
# [ OK ] decorator
# [ OK ] defusedxml
# [ OK ] exceptiongroup
# [ OK ] executing
# [ OK ] fastjsonschema
# [ OK ] fonttools
# [ OK ] fqdn
# [ OK ] frozendict
# [ OK ] h11
# [ OK ] html5lib
# [ OK ] httpcore
# [ OK ] httpx
# [ OK ] idna
# [ OK ] importlib_metadata
# [ OK ] importlib_resources
# [ OK ] iniconfig
# [ OK ] ipykernel
# [ OK ] ipython
# [ OK ] isoduration
# [ OK ] jedi
# [ OK ] jinja2
# [ OK ] joblib
# [ OK ] json5
# [ OK ] jsonpointer
# [FAIL] jsonschema[format_nongpl] not installed.
# [ OK ] jsonschema_specifications
# [ OK ] jupyter_client
# [ OK ] jupyter_core
# [ OK ] jupyter_events
# [ OK ] jupyter_lsp
# [ OK ] jupyter_server
# [ OK ] jupyter_server_terminals
# [ OK ] jupyterlab
# [ OK ] jupyterlab_pygments
# [ OK ] jupyterlab_server
# [ OK ] kiwisolver
# [ OK ] lxml
# [ OK ] markupsafe
# [ OK ] matplotlib
# [ OK ] matplotlib_inline
# [ OK ] mistune
# [ OK ] multitasking
# [ OK ] nbclient
# [ OK ] nbconvert
# [ OK ] nbformat
# [ OK ] nest_asyncio
# [ OK ] notebook_shim
# [ OK ] numpy
# [ OK ] overrides
# [ OK ] packaging
# [ OK ] pandas
# [ OK ] pandas_datareader
# [ OK ] pandocfilters
# [ OK ] parso
# [ OK ] patsy
# [ OK ] peewee
# [ OK ] pexpect
# [ OK ] pillow
# [ OK ] platformdirs
# [ OK ] pluggy
# [ OK ] prometheus_client
# [ OK ] prompt_toolkit
# [ OK ] psutil
# [ OK ] ptyprocess
# [ OK ] pure_eval
# [ OK ] pycparser
# [ OK ] pygments
# [ OK ] pyparsing
# [ OK ] pytest
# [ OK ] python_dateutil
# [ OK ] python_json_logger
# [ OK ] pytz
# [ OK ] pyyaml
# [ OK ] pyzmq
# [ OK ] referencing
# [ OK ] requests
# [ OK ] rfc3339_validator
# [ OK ] rfc3986_validator
# [ OK ] rpds_py
# [FAIL] sklearn not installed.
# [ OK ] scipy
# [ OK ] seaborn
# [ OK ] send2trash
# [ OK ] six
# [ OK ] sniffio
# [ OK ] soupsieve
# [ OK ] stack_data
# [ OK ] statsmodels
# [ OK ] tabulate
# [ OK ] terminado
# [ OK ] threadpoolctl
# [ OK ] tinycss2
# [ OK ] tomli
# [ OK ] tornado
# [ OK ] tqdm
# [ OK ] traitlets
# [ OK ] types_python_dateutil
# [ OK ] typing_extensions
# [ OK ] tzdata
# [ OK ] uri_template
# [ OK ] urllib3
# [ OK ] wcwidth
# [ OK ] webcolors
# [ OK ] webencodings
# [ OK ] websocket_client
# [ OK ] yfinance
# [ OK ] zipp
